# %%
####################################### Data Cleaning ###############################

import pandas as pd
#Remove non-ASCII characters

file_path = '/Users/rishikeshdhokare/Documents/Ironhack/MiniProject/mini-project-spotify/spotify_songs.csv'
df = pd.read_csv(file_path, encoding='utf-8')

def remove_non_ascii(text):
    # If value is not string (e.g., NaN), return it as is
    if not isinstance(text, str):
        return text
    return ''.join([char for char in text if ord(char) < 128])

df_cleaned = df.applymap(remove_non_ascii)
cleaned_file_path = '/Users/rishikeshdhokare/Documents/Ironhack/MiniProject/mini-project-spotify/spotify_songs_cleaned.csv'
df_cleaned.to_csv(cleaned_file_path, encoding='utf-8', index=False)

print("Non-ASCII characters removed and saved to new file.")
# Out:
# /var/folders/43/30gtvzf54299gghzdyc8_l900000gn/T/ipykernel_87683/1508921502.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_cleaned = df.applymap(remove_non_ascii)
# Non-ASCII characters removed and saved to new file.

# %%
#Check duplicates
duplicate_tracks = df[df.duplicated(subset='track_name', keep=False)]
print("Duplicate tracks based on 'track_name':")
print(duplicate_tracks)
num_duplicates = duplicate_tracks.shape[0]
print(f"\nTotal number of duplicate tracks: {num_duplicates}")
# Out:
# Duplicate tracks based on 'track_name':
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 5      7fvUMiyapMsRRxr07cU8Ef
# 7      6b1RNvAcJjQH73eZO4BLAB
# ...                       ...
# 32802  3Gwq0zKnMWluOEPKh93BeC
# 32804  2KlZexJjJPuNWcN5uAG1GU
# 32808  5QcSDOm6mcvFDl7KBT1fHv
# 32824  3zKST4nk4QJE77oLjUZ0Ng
# 32826  1EavLSmwRWtmkKEmlCfFzT
#
#                                               track_name    track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...      Ed Sheeran
# 1                        Memories - Dillon Francis Remix        Maroon 5
# 2                        All the Time - Don Diablo Remix    Zara Larsson
# 5      Beautiful People (feat. Khalid) - Jack Wins Remix      Ed Sheeran
# 7                Post Malone (feat. RANI) - GATTSO Remix       Sam Feldt
# ...                                                  ...             ...
# ...

# %%
matching_tracks = df[df['track_name'].str.contains("All the Time - Don Diablo Remix", case=False, na=False)]
matching_tracks
# Out:
#                      track_id                       track_name  track_artist  \
# 2      1z1Hg7Vb0AhHDiEmnDE79l  All the Time - Don Diablo Remix  Zara Larsson
# 28660  1z1Hg7Vb0AhHDiEmnDE79l  All the Time - Don Diablo Remix  Zara Larsson
# 29666  1z1Hg7Vb0AhHDiEmnDE79l  All the Time - Don Diablo Remix  Zara Larsson
#
#        track_popularity          track_album_id  \
# 2                    70  1HoSmj2eLcsrR0vE9gThr4
# 28660                70  1HoSmj2eLcsrR0vE9gThr4
# 29666                70  1HoSmj2eLcsrR0vE9gThr4
#
#                       track_album_name track_album_release_date  \
# 2      All the Time (Don Diablo Remix)               2019-07-05
# 28660  All the Time (Don Diablo Remix)               2019-07-05
# 29666  All the Time (Don Diablo Remix)               2019-07-05
#
#                   playlist_name             playlist_id playlist_genre  ...  \
# 2                     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...
# ...

# %%
import pandas as pd
file_path = '/Users/rishikeshdhokare/Documents/Ironhack/MiniProject/mini-project-spotify/spotify_songs_cleaned.csv'
df = pd.read_csv(file_path, encoding='utf-8')

# Remove duplicate rows based on the 'Title' column, keeping the first occurrence
df = df.drop_duplicates(subset='track_name', keep='first')

df.drop('loudness', axis=1, inplace=True)
df.drop('speechiness', axis=1, inplace=True)
df.drop('acousticness', axis=1, inplace=True)
df.drop('instrumentalness', axis=1, inplace=True)
df.drop('liveness', axis=1, inplace=True)
df.drop('valence', axis=1, inplace=True)
df.drop('tempo', axis=1, inplace=True)
df.drop('danceability', axis=1, inplace=True)
df.drop('energy', axis=1, inplace=True)
df.drop('key', axis=1, inplace=True)
df.drop('mode', axis=1, inplace=True)
df['duration_ms'] = df['duration_ms'] / 60000
cleaned_file_path = '/Users/rishikeshdhokare/Documents/Ironhack/MiniProject/mini-project-spotify/spotify_songs_no_duplicates.csv'
df_cleaned.to_csv(cleaned_file_path, encoding='utf-8', index=False)

# %%
df
# Out:
#                      track_id  \
# 0      6f807x0ima9a1j3VPbc7VN
# 1      0r7CVbZTWZgbTCYdfa2P31
# 2      1z1Hg7Vb0AhHDiEmnDE79l
# 3      75FpbthrwQmzHlBJLuGdC7
# 4      1e8PAfcKUYoKkxPhrHqw4x
# ...                       ...
# 32828  7bxnKAamR3snQ1VGLuVfC1
# 32829  5Aevni09Em4575077nkWHz
# 32830  7ImMqPP3Q1yfUHvsdn7wEo
# 32831  2m69mhnfQ1Oq6lGtXuYhgX
# 32832  29zWqhca3zt5NsckZqDf6c
#
#                                               track_name      track_artist  \
# 0      I Don't Care (with Justin Bieber) - Loud Luxur...        Ed Sheeran
# 1                        Memories - Dillon Francis Remix          Maroon 5
# 2                        All the Time - Don Diablo Remix      Zara Larsson
# 3                      Call You Mine - Keanu Silva Remix  The Chainsmokers
# 4                Someone You Loved - Future Humans Remix     Lewis Capaldi
# ...                                                  ...               ...
# ...
